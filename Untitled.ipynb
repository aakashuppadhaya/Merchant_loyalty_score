# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_new_merchant_transactions=pd.read_csv('new_merchant_transactions.csv')

# %%
Train=pd.read_csv('train.csv')

# %%
Test=pd.read_csv('test.csv')

# %%
Test.head()
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3
# 0            2017-04  C_ID_0ab67a22ab          3          3          1
# 1            2017-01  C_ID_130fd0cbdd          2          3          0
# 2            2017-08  C_ID_b709037bc5          5          1          1
# 3            2017-12  C_ID_d27d835a9f          2          1          0
# 4            2015-12  C_ID_2b5e3df5c2          5          1          1

# %%
Train.head()
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0            2017-06  C_ID_92a2005557          5          2          1
# 1            2017-01  C_ID_3d0044924f          4          1          0
# 2            2016-08  C_ID_d639edf6cd          2          2          0
# 3            2017-09  C_ID_186d6a6901          4          3          0
# 4            2017-11  C_ID_cdbd2c0db2          1          3          0
#
#      target
# 0 -0.820283
# 1  0.392913
# 2  0.688056
# 3  0.142495
# 4 -0.159749

# %%
merchant=pd.read_csv('merchants.csv')

# %%
df=Train.merge(df_new_merchant_transactions,how='inner',on='card_id')

# %%
d=df.merge(merchant,how='inner',on='merchant_id')

# %%
d.to_csv('train_final.csv')

# %%
df_new_merchant_transactions.head()
# Out:
#   authorized_flag          card_id  city_id category_1  installments  \
# 0               Y  C_ID_415bb3a509      107          N             1
# 1               Y  C_ID_415bb3a509      140          N             1
# 2               Y  C_ID_415bb3a509      330          N             1
# 3               Y  C_ID_415bb3a509       -1          Y             1
# 4               Y  C_ID_ef55cf8d4b       -1          Y             1
#
#   category_3  merchant_category_id      merchant_id  month_lag  \
# 0          B                   307  M_ID_b0c793002c          1
# 1          B                   307  M_ID_88920c89e8          1
# 2          B                   507  M_ID_ad5237ef6b          2
# 3          B                   661  M_ID_9e84cda3b1          1
# 4          B                   166  M_ID_3c86fa3831          1
#
#    purchase_amount        purchase_date  category_2  state_id  subsector_id
# 0        -0.557574  2018-03-11 14:57:36         1.0         9            19
# ...

# %%
result = pd.merge(Test, df_new_merchant_transactions, how='inner', on=['card_id'])

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 743346 entries, 0 to 743345
# Data columns (total 18 columns):
# first_active_month      743346 non-null object
# card_id                 743346 non-null object
# feature_1               743346 non-null int64
# feature_2               743346 non-null int64
# feature_3               743346 non-null int64
# authorized_flag         743346 non-null object
# city_id                 743346 non-null int64
# category_1              743346 non-null object
# installments            743346 non-null int64
# category_3              722108 non-null object
# merchant_category_id    743346 non-null int64
# merchant_id             733400 non-null object
# month_lag               743346 non-null int64
# purchase_amount         743346 non-null float64
# purchase_date           743346 non-null object
# category_2              700652 non-null float64
# state_id                743346 non-null int64
# subsector_id            743346 non-null int64
# ...

# %%
result.to_csv('testid.csv')

# %%
result.drop_duplicates(subset=['card_id'], keep=False)
# Out:
#        first_active_month          card_id  feature_1  feature_2  feature_3  \
# 30                2017-07  C_ID_5814b4f13c          5          1          1
# 68                2016-08  C_ID_7f1041e8e1          5          1          1
# 105               2016-05  C_ID_b54cfad8b2          2          2          0
# 108               2016-04  C_ID_60a453531a          3          2          1
# 144               2014-12  C_ID_5005a6ad0e          3          1          1
# 187               2017-09  C_ID_74ff4fdd9d          2          1          0
# 204               2017-03  C_ID_66715f7d2b          3          1          1
# 255               2017-11  C_ID_8f9dc072c4          2          1          0
# 279               2017-09  C_ID_e9771fd0b3          2          1          0
# 319               2015-12  C_ID_59406e1778          2          2          0
# 398               2017-02  C_ID_ac88d17815          2          2          0
# ...

# %%
g=result.groupby('card_id')

# %%
df=g.get_group('C_ID_0ab67a22ab')

# %%
aggregation_functions = {'purchase_amount': 'sum','feature_1':'max'}
df=df.groupby(df['card_id']).aggregate(aggregation_functions)

# %%
df
# Out:
#                  purchase_amount  feature_1
# card_id
# C_ID_0ab67a22ab        -1.777156          3

# %%
result['authorized_flag']=result.authorized_flag.eq('Y').mul(1)

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 743346 entries, 0 to 743345
# Data columns (total 18 columns):
# first_active_month      743346 non-null object
# card_id                 743346 non-null object
# feature_1               743346 non-null int64
# feature_2               743346 non-null int64
# feature_3               743346 non-null int64
# authorized_flag         743346 non-null int32
# city_id                 743346 non-null int64
# category_1              743346 non-null object
# installments            743346 non-null int64
# category_3              722108 non-null object
# merchant_category_id    743346 non-null int64
# merchant_id             733400 non-null object
# month_lag               743346 non-null int64
# purchase_amount         743346 non-null float64
# purchase_date           743346 non-null object
# category_2              700652 non-null float64
# state_id                743346 non-null int64
# subsector_id            743346 non-null int64
# ...

# %%
df=result['feature_1'].unique()

# %%
len(df)
# Out:
# 5
